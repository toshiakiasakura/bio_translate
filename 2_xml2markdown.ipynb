# %% [markdown]
# # bio trans to markdown

# %%
from tqdm import tqdm
from Bio import Entrez
import xml.etree.ElementTree as ET
import requests
import re
import json
from googletrans import Translator 
import bio_trans
import os
import urllib.parse
import pandas as pd
import numpy as np 
import pubmed_parser as pp

# %load_ext autoreload
# %autoreload 2

# %%
bio_trans.check_journal_in_PMC("Allergy")
# Out:
# Allergy, Asthma, and Clinical Immunology : Official Journal of the Canadian Society of Allergy and Clinical Immunology
# Allergy, Asthma &#x0026; Immunology Research
# Allergy and Asthma Proceedings
# Allergy &#x0026; Rhinology
# American Journal of Rhinology &#x0026; Allergy
# Asia Pacific Allergy
# Clinical and Molecular Allergy : CMA
# Clinical and Translational Allergy
# International Archives of Allergy and Immunology
# ISRN Allergy
# Journal of Allergy
# Journal of Asthma and Allergy
# Pediatric Allergy, Immunology, and Pulmonology
# The World Allergy Organization Journal
#                                           Journal title  \
# 118   Allergy, Asthma, and Clinical Immunology : Off...
# 119        Allergy, Asthma &#x0026; Immunology Research
# 120                      Allergy and Asthma Proceedings
# 121                          Allergy &#x0026; Rhinology
# 162      American Journal of Rhinology &#x0026; Allergy
# 302                                Asia Pacific Allergy
# 867                Clinical and Molecular Allergy : CMA
# 888                  Clinical and Translational Allergy
# 1563   International Archives of Allergy and Immunology
# 1768                                       ISRN Allergy
# 1825                                 Journal of Allergy
# 1862                      Journal of Asthma and Allergy
# 2957     Pediatric Allergy, Immunology, and Pulmonology
# 3505             The World Allergy Organization Journal
#
#                                 NLM TA      pISSN      eISSN  \
# 118        Allergy Asthma Clin Immunol  1710-1484  1710-1492
# 119         Allergy Asthma Immunol Res  2092-7355  2092-7363
# 120                Allergy Asthma Proc  1088-5412  1539-6304
# 121        Allergy Rhinol (Providence)  2152-6575  2152-6567
# 162                Am J Rhinol Allergy  1945-8924  1945-8932
# 302                   Asia Pac Allergy  2233-8276  2233-8268
# 867                   Clin Mol Allergy        NaN  1476-7961
# 888                Clin Transl Allergy        NaN  2045-7022
# 1563          Int Arch Allergy Immunol  1018-2438  1423-0097
# 1768                      ISRN Allergy  2090-5521  2090-553X
# 1825                 J Allergy (Cairo)  1687-9783  1687-9791
# 1862                  J Asthma Allergy        NaN  1178-6965
# 2957  Pediatr Allergy Immunol Pulmonol  2151-321X  2151-3228
# 3505             World Allergy Organ J        NaN  1939-4551
#
#                                               Publisher LOCATORplus ID  \
# 118                                      BioMed Central      101244313
# 119   Korean Academy of Asthma, Allergy and Clinical...      101518382
# 120                              OceanSide Publications        9603640
# 121                                   SAGE Publications      101570968
# 162                                   SAGE Publications      101490775
# 302   Asia Pacific Association of Allergy, Asthma an...      101561954
# 867                                      BioMed Central      101152195
# 888                                      BioMed Central      101576043
# 1563                                  Karger Publishers        9211652
# 1768                                    Hindawi Limited      101605568
# 1825                                    Hindawi Limited      101535174
# 1862                                         Dove Press      101543450
# 2957                             Mary Ann Liebert, Inc.      101549629
# 3505                         World Allergy Organization      101481283
#
#                 Latest issue Earliest volume Free access Open access  \
# 118                v.16;2020        v.1;2005   Immediate         All
# 119         v.12(5);Sep 2020        v.1;2009   Immediate         All
# 120         v.41(5);Sep 2020       v.33;2012   Immediate          No
# 121        v.11;Jan-Dec 2020        v.2;2011   Immediate         All
# 162         v.34(4);Jul 2020       v.25;2011   Immediate          No
# 302         v.10(3);Jul 2020        v.1;2011   Immediate         All
# 867                v.18;2020        v.1;2003   Immediate        Some
# 888                v.10;2020        v.1;2011   Immediate         All
# 1563       v.161(4);Jul 2013      v.147;2008         NaN        Some
# 1768             v.2014;2014     v.2011;2011         NaN         All
# 1825             v.2017;2017     v.2009;2009         NaN         All
# 1862               v.13;2020        v.1;2008   Immediate         All
# 2957  v.33(3);September 2020       v.23;2010   12 months        Some
# 3505       v.13(10);Oct 2020        v.1;2008   Immediate         All
#
#      Participation level    Deposit status  \
# 118                Full
# 119                Full
# 120       NIH Portfolio
# 121                Full
# 162       NIH Portfolio
# 302                Full
# 867                Full
# 888                Full
# 1563      NIH Portfolio    No New Content
# 1768               Full    No New Content
# 1825               Full    No New Content
# 1862               Full
# 2957               Full
# 3505               Full
#
#                                             Journal URL
# 118       http://www.ncbi.nlm.nih.gov/pmc/journals/992/
# 119      http://www.ncbi.nlm.nih.gov/pmc/journals/1188/
# 120   http://www.ncbi.nlm.nih.gov/pmc/?term=%22Aller...
# 121      http://www.ncbi.nlm.nih.gov/pmc/journals/1781/
# 162   http://www.ncbi.nlm.nih.gov/pmc/?term=%22Am+J+...
# 302      http://www.ncbi.nlm.nih.gov/pmc/journals/1658/
# 867       http://www.ncbi.nlm.nih.gov/pmc/journals/226/
# 888      http://www.ncbi.nlm.nih.gov/pmc/journals/1751/
# 1563  http://www.ncbi.nlm.nih.gov/pmc/?term=%22Int+A...
# 1768     http://www.ncbi.nlm.nih.gov/pmc/journals/2096/
# 1825     http://www.ncbi.nlm.nih.gov/pmc/journals/1313/
# 1862     http://www.ncbi.nlm.nih.gov/pmc/journals/1443/
# 2957     http://www.ncbi.nlm.nih.gov/pmc/journals/1568/
# 3505     http://www.ncbi.nlm.nih.gov/pmc/journals/1903/

# %%
df_doi = pd.read_csv("./doi_management.csv")
cond = df_doi["flag"] == 1
df_valid = df_doi.loc[cond]
display(df_valid)
DOIs = df_valid["doi"].unique()
doi = DOIs[3]
for i, r in df_valid.iterrows():
    bio_trans.save_xml(r["doi"],r["NUS_name"])
# Out:
#    index                         doi            NUS_name journal_name  flag
# 0      6      10.3390/ijerph15112487          068_sanyal          NaN     1
# 3      2      10.1001/jama.2019.5357          008_Garcia          NaN     1
# 4      3  10.1164/rccm.201806-1161OC             012_Lim          NaN     1
# 5      4   10.1038/s41370-019-0135-4  015_Kazemiparkouhi          NaN     1

# %%
name = "015_Kazemiparkouhi"
const_md = bio_trans.MDConstructor(name)
# Out:
# google trans: 100%|██████████| 68/68 [00:19<00:00,  3.51it/s]

# %%
const_md.keywords =  ["O3", "ozone", "O 3"]
const_md.model_keywords = ["model", "regression", "モデル", "回帰"]

# %%
const_md.convert2md()
